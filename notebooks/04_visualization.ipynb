# %% [markdown]
# # 04 - Visualization & Exploration
# ## A/B Testing Campaign Analysis
#
# This notebook creates visualizations for distributions, segment analysis, and KPIs.

# %%
import pandas as pd
import numpy as np
import sys
sys.path.insert(0, '../src')
from visualizations import Visualizations
import plotly.graph_objects as go

# %% [markdown]
# ## 1. Distribution Plots

# %%
# Load data
# df = pd.read_csv('../data/processed/cleaned_data.csv')
# control_metric = df[df['variant'] == 'control']['metric'].values
# treatment_metric = df[df['variant'] == 'treatment']['metric'].values

# Create distribution plot
# fig_dist = Visualizations.distribution_plot(
#     control_metric, treatment_metric,
#     title="Distribution Comparison: Control vs Treatment",
#     xlabel="Metric Value"
# )
# fig_dist.show()

# %% [markdown]
# ## 2. Box Plot Comparison

# %%
# Create box plot
# fig_box = Visualizations.box_plot(
#     df, x='variant', y='metric',
#     title="Metric Distribution by Variant"
# )
# fig_box.show()

# %% [markdown]
# ## 3. KPI Cards

# %%
# Generate KPI metrics
# metrics = {
#     'Control Mean': df[df['variant'] == 'control']['metric'].mean(),
#     'Treatment Mean': df[df['variant'] == 'treatment']['metric'].mean(),
#     'Improvement %': ((df[df['variant'] == 'treatment']['metric'].mean() - 
#                       df[df['variant'] == 'control']['metric'].mean()) / 
#                      df[df['variant'] == 'control']['metric'].mean() * 100)
# }

# kpi_data = Visualizations.kpi_cards(metrics)
# print("KPI Cards:")
# for kpi in kpi_data['kpis']:
#     print(f"  {kpi['label']}: {kpi['value']}")

# %% [markdown]
# ## 4. Segment Analysis Heatmap

# %%
# Create segment analysis example data
# segment_data = pd.DataFrame({
#     'segment': ['Mobile', 'Desktop', 'Mobile', 'Desktop'],
#     'metric': ['Conversion', 'Conversion', 'AOV', 'AOV'],
#     'p_value': [0.023, 0.156, 0.001, 0.234]
# })

# fig_heatmap = Visualizations.segment_heatmap(
#     segment_data,
#     x_col='segment',
#     y_col='metric',
#     value_col='p_value',
#     title="Statistical Significance by Segment"
# )
# fig_heatmap.show()

# %% [markdown]
# ## 5. Effect Size Visualization

# %%
# Create effect size plot
# effect_sizes = {
#     'Overall': 0.15,
#     'Mobile': 0.22,
#     'Desktop': 0.08,
#     'US': 0.18,
#     'EU': 0.12
# }

# fig_effect = Visualizations.effect_size_plot(
#     effect_sizes,
#     title="Effect Sizes (Cohen's d) by Segment"
# )
# fig_effect.show()

# %% [markdown]
# ## 6. Next Steps
#
# 1. Run this after statistical tests
# 2. Export visualizations for reports
# 3. Use 05_report_summary.ipynb for final recommendations
