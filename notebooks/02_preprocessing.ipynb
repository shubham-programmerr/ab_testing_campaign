# %% [markdown]
# # 02 - Data Preprocessing
# ## A/B Testing Campaign Analysis
#
# This notebook handles data cleaning, validation, and Sample Ratio Mismatch checks.

# %%
import pandas as pd
import numpy as np
import sys
sys.path.insert(0, '../src')
from data_loader import DataLoader
from preprocessing import DataPreprocessor
from utils import load_config

# %% [markdown]
# ## 1. Load Data

# %%
# Load configuration
config = load_config('../config.yaml')
loader = DataLoader(data_dir='../data/raw')

# Load data (update filename as needed)
# df = loader.load_csv('ab_test_data.csv')
# print(f"Data loaded: {len(df)} rows, {len(df.columns)} columns")

# %% [markdown]
# ## 2. Check Sample Ratio Mismatch (SRM)

# %%
# Initialize preprocessor
preprocessor = DataPreprocessor()

# Check for SRM
# srm_result = preprocessor.check_sample_ratio_mismatch(
#     df, alpha=config['data_validation']['srm_threshold']
# )
# print("Sample Ratio Mismatch Check:")
# for key, value in srm_result.items():
#     print(f"  {key}: {value}")

# %% [markdown]
# ## 3. Data Cleaning Pipeline

# %%
# Prepare data using preprocessing pipeline
# numeric_columns = df.select_dtypes(include=[np.number]).columns.tolist()
# df_clean = preprocessor.prepare_for_analysis(df, numeric_cols=numeric_columns)

# print(f"\nCleaned data: {len(df_clean)} rows")
# print(f"Processing log:")
# for log in preprocessor.get_processing_log():
#     print(f"  - {log}")

# %% [markdown]
# ## 4. Save Processed Data

# %%
# Save cleaned data for next steps
# output_path = '../data/processed/cleaned_data.csv'
# df_clean.to_csv(output_path, index=False)
# print(f"Processed data saved to: {output_path}")

# %% [markdown]
# ## 5. Next Steps
#
# 1. Run this notebook after EDA
# 2. Review preprocessing logs
# 3. Proceed to 03_statistical_tests.ipynb
