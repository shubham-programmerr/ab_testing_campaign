# %% [markdown]
# # 01 - Exploratory Data Analysis (EDA)
# ## A/B Testing Campaign Analysis
#
# This notebook performs initial data exploration and quality checks.

# %%
import pandas as pd
import numpy as np
import sys
sys.path.insert(0, '../src')
from data_loader import DataLoader
from utils import load_config

# %% [markdown]
# ## 1. Load Configuration and Data

# %%
# Load configuration
config = load_config('../config.yaml')
print("Configuration loaded successfully")
print(f"Alpha level: {config['statistical_tests']['default_alpha']}")
print(f"Confidence level: {config['statistical_tests']['confidence_level']}")

# %%
# Initialize data loader and load sample data
loader = DataLoader(data_dir='../data/raw')

# Note: You'll need to add your CSV file to data/raw/
# Example: df = loader.load_csv('ab_test_data.csv')
print("Data loader initialized")
print(f"Data directory: ../data/raw/")

# %% [markdown]
# ## 2. Data Quality Checks
#
# Uncomment below when data is loaded

# %%
# Validate data structure
# try:
#     loader.validate_ab_data(df)
#     print("✓ Data validation passed")
# except ValueError as e:
#     print(f"✗ Validation error: {e}")

# %%
# Check data quality metrics
# quality_report = loader.check_data_quality(df)
# for key, value in quality_report.items():
#     print(f"{key}: {value}")

# %% [markdown]
# ## 3. Exploratory Analysis
#
# Uncomment below when data is loaded

# %%
# Split by variant
# control, treatment = loader.split_by_variant(df)
# print(f"Control group size: {len(control)}")
# print(f"Treatment group size: {len(treatment)}")
# print(f"Ratio: {len(treatment) / len(control):.2f}")

# %%
# Display summary statistics
# print("\nControl Group Statistics:")
# print(control['metric'].describe())
# print("\nTreatment Group Statistics:")
# print(treatment['metric'].describe())

# %% [markdown]
# ## 4. Next Steps
#
# 1. Load your A/B test data into `data/raw/`
# 2. Update the data loading code above
# 3. Proceed to 02_preprocessing.ipynb for data cleaning
# 4. Then run 03_statistical_tests.ipynb for analysis
